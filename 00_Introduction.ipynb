# %% [markdown]
# <a href="https://colab.research.google.com/github/mrArpanM/learn-python/blob/main/00_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Coding for even 7 year old !!** 🔥🔥

# %% [markdown]
# ## কম্পিউটার সবকিছুই এই একটি সহজ নীতি অনুসরণ করে [Everything in computer science follows this one simple principle.]
#
# ![cs50Week0Slide38.png](data:image/png;base64,...)
#
# *ডায়াগ্রামটি [CS50 by David J  Malan](https://www.edx.org/course/introduction-computer-science-harvardx-cs50x) (হার্ভার্ড ইউনিভার্সিটি, কম্পিউটার সায়েন্সে অত্যন্ত সুপারিশকৃত বিনামূল্যের পরিচায়ক কোর্স) থেকে নেওয়া হয়েছে।*
#
# *This diagram is taken from the  [CS50 by David J Malan](https://www.edx.org/course/introduction-computer-science-harvardx-cs50x) (Highly recommended free **introductory course in computer science** from Harvard University)*

# %% [markdown]
# ## **একজন কোডার হিসেবে আপনার কাজ হল বক্সকে কীভাবে আচরণ করতে হয় তা শেখানো।**
# ## **As a coder, Your job is tell the box how to behave.**
#
# ---

# %% [markdown]
# ### 😀 kaputt= সর্বনাশ
#
# ![input-output-kaputt.jpg](data:image/jpeg;base64,...)
#
# ---

# %% [markdown]
# ## 🐍 What is python? [পাইথন কি?]
#
# **পাইথন হল একটি কম্পিউটার (প্রোগ্রামিং) ভাষা যা আমরা বাক্সটিকে বিভিন্ন পরিস্থিতিতে কীভাবে আচরণ করতে হয় তা শেখাতে ব্যবহার করি।**
#
# পাইথন হল একটি সাধারণ-উদ্দেশ্যের ভাষা যার খুব মানুষের পাঠযোগ্য সিনট্যাক্স রয়েছে [সিনট্যাক্স মানুষের ভাষায় বর্ণমালা এবং ব্যাকরণের অনুরূপ]। তাই, এটি বিভিন্ন ধরণের বিভিন্ন প্রোগ্রাম তৈরি করতে ব্যবহার করা যেতে পারে এবং শিখতে খুব সহজ। তাই প্রোগ্রামিং এর সাধারণ ধারণার সাথে পরিচিত হওয়ার জন্য এটি প্রায় একটি আদর্শ ভাষা।
#
# পাইথন প্রায়শই সফ্টওয়্যার তৈরি করতে, যেকোনো কাজ স্বয়ংক্রিয় করতে এবং ডেটা বিশ্লেষণ এবং এমনকি মেশিন লার্নিং মডেল, নিউরাল নেটওয়ার্ক ইত্যাদি তৈরির মতো জটিল কাজগুলি পরিচালনা করতে ব্যবহৃত হয়।
#
# **Python is a computer (programming) language to let know the rectangle on how to behave in different circumstances. Python is a general-purpose language with very human readable syntax [Syntax is similar to the scripts & grammer in a human language], meaning it can be used to create a variety of different programs and isn't specialized for any specific problems, that's why it is almost an ideal language to get femilier with the concepts of programming.**
#
# Python is often used to build software, automate tasks, and conduct data analysis & complex tasks like building machine learning models, neural networks etc.
#
# ---

# %% [markdown]
# ## 📔 What is Jupyter Notebook(& Google colab)? [জুপিটার নোটবুক (এবং গুগল কোল্যাব) কি?]
#
# **যেমন আপনি ছোটবেলায় হাত দিয়ে লেখার জন্য খাতা ব্যবহার করেছেন। জুপিটার নোটবুকগুলিকে হাতের লেখার পরিবর্তে টাইপ করে কোড এবং মার্কডাউন (স্বাভাবিক) পাঠ্য লেখার জন্য খাতা হিসাবে ভাবুন, যা কাগজে হাতের লেখার চেয়ে আরও কার্যকর এবং যুক্তিযুক্তভাবে পরিবেশ বান্ধব উপায়।**
#
# এটি একটি ইন্টারেক্টিভ ডেটা সায়েন্স এবং বৈজ্ঞানিক কম্পিউটিং এর ওয়েব অ্যাপ্লিকেশন যা কম্পিউটেশনাল ডকুমেন্ট তৈরি এবং শেয়ার করার জন্য আদর্শ। এটি একটি সহজ, সুবিন্যস্ত, নথি-কেন্দ্রিক অভিজ্ঞতা প্রদান করে। এটির দুটি উপাদান রয়েছে: একটি ফ্রন্ট-এন্ড ওয়েব পেজ এবং একটি ব্যাক-এন্ড কার্নেল। ফ্রন্ট-এন্ড ওয়েব পেজ ডেটা বিজ্ঞানীদের প্রোগ্রামিং কোড বা পাঠ্য আয়তক্ষেত্রাকার "কোষ" এ প্রবেশ করতে দেয়। ব্রাউজার তারপর কোডটি ব্যাক-এন্ড কার্নেলে পাস করে যা কোড চালায় এবং ফলাফল প্রদান করে।
#
# The Google colab Jupyter Notebook is an interactive data science and scientific computing  web application for creating and sharing computational documents. It offers a simple, streamlined, document-centric experience. It has two components: a front-end web page and a back-end kernel. The front-end web page allows data scientists to enter programming code or text in rectangular "cells." The browser then passes the code to the back-end kernel which runs the code and returns the results.
#
# **As you've used normal notebooks for writing with your hand when you were little kids. Think of jupyter notebooks as notebooks for writing codes & markdown(normal) texts by typing instead of handwriting, Which is way more efficent & arguably more environment friendly way of writing than handwriting on papers.**
#
# ---

# %% [markdown]
# ### Stats:
# *👉 Average typing speed is 40 word per minute, which anyone can attain very easily with few months of practice & the highest typing speed is 216 word per minute whereas handwriting speed float between 3-26 word per minute. It is almost humanly impossible to reach 40wpm with your handwriting.*
#
# *🌴 Around 4 to 15 billion trees are cut every single year worldwide in order to create papers to print notebooks or books.*

# %% [markdown]
# ## 🤞 Writing your first program in python inside a jupyter notebook!

# %%
# Before you understand anything, run this cell.
print("hello world!")

# %% [markdown]
# ### Voila!! You're officially a programmer now.
# ### অসাধারণ!! আপনি এখন আনুষ্ঠানিকভাবে একজন প্রোগ্রামার।
#
# We will learn what this above line of code means from module 2 but before that we'll learn more about jupyter notebooks in more details and primarily jupyter notebooks instances provided by google colab as we'll be working in this environment for this interactive course.
#
# আমরা মডিউল 3 থেকে উপরের কোডগুলি সম্পর্কে শিখব কিন্তু তার আগে, আমরা জুপিটার নোটবুক সম্পর্কে আরও বিস্তারিতভাবে শিখব কারণ আমরা এই ইন্টারেক্টিভ কোর্সের জন্য এই পরিবেশে কাজ করব।
