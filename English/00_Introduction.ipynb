# %% [markdown]
# # **Coding for even 7 year old !!**
#
# ## Everything in computer science follows this one simple principle.
#
# ![cs50Week0Slide38.png](data:image/png;base64,...)
#
# *The diagram is taken from the  [CS50 by David J Malan](https://www.edx.org/course/introduction-computer-science-harvardx-cs50x) (Highly recommended free **introductory course in computer science** from Harvard University)*
#
# ## **You as a coder, Your job is tell the rectangle how to behave.**
#
#
#
# ---
#
#
#
# ## What is python?
#
# **Python is a computer (programming) language to let know the rectangle on how to behave in different circumstances. Python is a general-purpose language with very human readable syntax [Syntax is similar to the scripts & grammer in a human language], meaning it can be used to create a variety of different programs and isn't specialized for any specific problems, that's why it is almost an ideal language to get femilier with the concepts of programming.**
#
# Python is often used to build software, automate tasks, and conduct data analysis & complex tasks like building machine learning models, neural networks etc.
#
#
# ---
#
#
# ## What is Jupyter Notebook (& also Google colab)?
#
# The Google colab Jupyter Notebook is an interactive data science and scientific computing  web application for creating and sharing computational documents. It offers a simple, streamlined, document-centric experience. It has two components: a front-end web page and a back-end kernel. The front-end web page allows data scientists to enter programming code or text in rectangular "cells." The browser then passes the code to the back-end kernel which runs the code and returns the results.
#
# **As you've used normal notebooks for writing with your hand when you were little kids. Think of jupyter notebooks as notebooks for writing codes & markdown(normal) texts by typing instead of handwriting, Which is way more efficent & arguably more environment friendly way of writing than handwriting on papers.**
#
#
# ### Stats:
# *Average typing speed is 40 word per minute, which anyone can attain very easily with few months of practice & the highest typing speed is 216 word per minute whereas handwriting speed float between 3-26 word per minute. It is almost humanly impossible to reach 40wpm with your handwriting.*
#
# *Around 4 to 15 billion trees are cut every single year worldwide in order to create papers to print notebooks or books.*

# %% [markdown]
# ## Writing your first program in python inside a jupyter notebook!

# %%
# Before you understand anything, run this cell.
print("hello world!")

# %% [markdown]
# ### Voila!! You're official a programmer now.
#
# We will learn what this above line of code means from module 2 but before that we'll learn more about jupyter notebooks in more details and primarily jupyter notebooks instances provided by google colab as we'll be working in this environment for this interactive course.

# %% [markdown]
# ## Modules
#
# | Modules | Topics | Description |
# |:--:|:--:|:--:|
# | 00 | Introduction | Objectives and overview of this bootcamp |
# | 01 | Vedic Maths | Basic mathematical concepts that you will/may need |
# | 02 | Colab Notebook | How to use jupyter notebook instance provided by google colab |
# | 03 | Python Overview | Basics of python.|
# | 04 | Operations | Basics operations such as conditional, loops, functions and classes. |
# | 05 | Modules | Overview of popular modules such as numpy, pandas, matplotlib and pytorch. |
# | 06 | Programming paradigms | Introduction of functional and object oriented programming |
# | 07 | Fun Projects | We will make some fun projects together. |
# | 08 | AI | Introduction to computational intelligence |
# | 09 | Agent Development | Deep reinforcement learning with human feedback |

# %% [markdown]
# This is what you genuinely need to learn.This is just a way.
#
# It is not recommended to buy(or get) certification. Instead work on building a strong portfolio of projects that shows your command on this skillset.
#
# Then start freelancing and start your own venture along with your fellow classmates to earn you financial independence, then learn what makes you curious and do what you like and follow your passion.

# %% [markdown]
# ## Objectives:
#
# *  Ensure a solid understanding of the basics: Help the learner grasp fundamental programming concepts such as variables, data types, and basic syntax.
#
# * Foster problem-solving skills: Encourage the learner to think critically and apply programming concepts to solve simple problems. Support them in breaking down problems into smaller steps and guide them in developing logical solutions.
#
# * Familiarize with control flow and loops: Introduce if statements and loops, enabling the learner to make decisions and repeat code blocks. Provide examples and exercises to reinforce understanding.
#
# * Cultivate the ability to create reusable code: Teach the learner how to define and use functions to organize and reuse code. Encourage them to think about modular programming and breaking down tasks into smaller, manageable functions.
#
# * Encourage creativity and project-based learning: Inspire the learner to explore coding through creative projects aligned with their interests. Assist them in brainstorming and developing small projects that allow them to apply their knowledge and foster enthusiasm for programming.
